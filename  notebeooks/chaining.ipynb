# %% [markdown]
# ### Load ENV and LLM

# %%
from calendar import prmonth

from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant")

# %% [markdown]
# ### Create Messages

# %%
from langchain_core.prompts import ChatPromptTemplate

st_msg = "Convert the user text into specific language {language}"

prompt = ChatPromptTemplate.from_messages(
    [
        ("system",st_msg),
        ("user","{input}")
    ]
)
prompt.invoke({
    "language":"Hindi",
    "input":"Hi How are you"
})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Convert the user text into specific language Hindi', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hi How are you', additional_kwargs={}, response_metadata={})])

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt|model|StrOutputParser()

chain.invoke({
    "language":"Hindi",
    "input":"Hi How are you"

})
# Out:
# 'नमस्ते मैं ठीक हूँ, धन्यवाद।'
