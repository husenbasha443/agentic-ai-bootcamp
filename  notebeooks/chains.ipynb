# %% [markdown]
# ### Load ENV and LLM

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant")

# %% [markdown]
# ### Create a Prompt

# %% [markdown]
# ### Create a Chain

# %%
from langchain_core.prompts import ChatPromptTemplate

template = "Convert Specific Language into {language}"

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", template),
        ("user","{input}")
    ]
)

result = prompt.invoke({
    "language":"Kannada",
    "input":"My Name is Husen"
})
result
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Convert Specific Language into Kannada', additional_kwargs={}, response_metadata={}), HumanMessage(content='My Name is Husen', additional_kwargs={}, response_metadata={})])

# %%
from langchain_core.output_parsers import StrOutputParser
chain = prompt|model|StrOutputParser()
chain.invoke({
    "language":"Kannada",
    "input":"My Name is Husen"
})
# Out:
# 'ನಿಮ್ಮ ಹೆಸರು ಹುಸೇನ್.'
